# %%
import pandas as pd
import numpy as np
from itertools import product
import math

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# ============================================================
# 1. LOAD DATA
# ============================================================
df = pd.read_csv('Adult_clean.csv')

# take only needed columns for model
nodes = [
    'age_bin', 'race', 'sex', 'native-country', 'education',
    'occupation', 'workclass', 'hours_bin', 'marital-status', 'income'
]

df = df[nodes].copy()

for col in df.columns:
    df[col] = df[col].astype(str)

df
# Out:
#       age_bin                race     sex native-country   education  \
# 0       Adult               White    Male             US   Bachelors
# 1      Middle               White    Male             US   Bachelors
# 2       Adult               White    Male             US     HS-grad
# 3      Middle               Black    Male             US  HS-or-less
# 4       Adult               Black  Female          Other   Bachelors
# ...       ...                 ...     ...            ...         ...
# 48837   Adult               White  Female             US   Bachelors
# 48838  Middle               Black    Male             US     HS-grad
# 48839   Adult               White    Male             US   Bachelors
# 48840   Adult  Asian-Pac-Islander    Male             US   Bachelors
# 48841   Adult               White    Male             US   Bachelors
#
#               occupation         workclass  hours_bin      marital-status  \
# 0           Adm-clerical               Gov  Full-time       Never-married
# 1        Exec-managerial  Private/Self-emp  Part-time  Married-civ-spouse
# 2      Handlers-cleaners  Private/Self-emp  Full-time            Divorced
# 3      Handlers-cleaners  Private/Self-emp  Full-time  Married-civ-spouse
# 4         Prof-specialty  Private/Self-emp  Full-time  Married-civ-spouse
# ...                  ...               ...        ...                 ...
# 48837     Prof-specialty  Private/Self-emp  Full-time            Divorced
# 48838            Missing           Missing  Full-time             Widowed
# 48839     Prof-specialty  Private/Self-emp       Long  Married-civ-spouse
# 48840       Adm-clerical  Private/Self-emp  Full-time            Divorced
# 48841    Exec-managerial  Private/Self-emp       Long  Married-civ-spouse
#
#       income
# 0      <=50K
# 1      <=50K
# 2      <=50K
# 3      <=50K
# 4      <=50K
# ...      ...
# 48837  <=50K
# 48838  <=50K
# 48839  <=50K
# 48840  <=50K
# 48841   >50K
#
# [48842 rows x 10 columns]

# %%
# ============================================================
# 2. SPLIT TRAINING AND TESTING SET (80/20)
# ============================================================

# shuffled data
shuffled = df.sample(frac=1.0, random_state=42).reset_index(drop=True)

# split data by index
split_idx = int(0.8 * len(shuffled))
train = shuffled.iloc[:split_idx].copy()
test = shuffled.iloc[split_idx:].copy()

# %%
# ============================================================
# 3. MODEL 2 STRUCTURE
# ============================================================
parents = {
    'age_bin': [],
    'race': [],
    'sex': [],
    'native-country': [],
    'education': ['age_bin', 'race', 'sex', 'native-country'],
    'occupation': ['education'],
    'workclass': ['education'],
    'hours_bin': ['occupation', 'workclass'],
    'marital-status': ['age_bin'],
    'income': ['marital-status', 'education', 'occupation', 'hours_bin']
}

# sanity check: keys in parents must match nodes
assert set(parents.keys()) == set(nodes)

# all possible states from TRAINING data
states = {col: sorted(train[col].unique())for col in nodes}
states
# Out:
# {'age_bin': ['Adult', 'Middle', 'Senior', 'Young'],
#  'race': ['Amer-Indian-Eskimo',
#   'Asian-Pac-Islander',
#   'Black',
#   'Other',
#   'White'],
#  'sex': ['Female', 'Male'],
#  'native-country': ['Asia',
#   'Europe',
#   'Latin-America',
#   'Missing',
#   'Other',
#   'US'],
#  'education': ['Bachelors',
#   'Grad',
#   'HS-grad',
#   'HS-or-less',
#   'Some-college/Assoc'],
#  'occupation': ['Adm-clerical',
#   'Armed-Forces',
#   'Craft-repair',
#   'Exec-managerial',
#   'Farming-fishing',
#   'Handlers-cleaners',
#   'Machine-op-inspct',
#   'Missing',
#   'Other-service',
#   'Priv-house-serv',
#   'Prof-specialty',
#   'Protective-serv',
#   'Sales',
#   'Tech-support',
#   'Transport-moving'],
#  'workclass': ['Gov', 'Missing', 'Not-working', 'Private/Self-emp'],
#  'hours_bin': ['Extreme', 'Full-time', 'Long', 'Part-time'],
#  'marital-status': ['Divorced',
#   'Married-AF-spouse',
#   'Married-civ-spouse',
#   'Married-spouse-absent',
#   'Never-married',
#   'Separated',
#   'Widowed'],
#  'income': ['<=50K', '>50K']}

# %%
# ============================================================
# 4. Learn CPTs with MLE + Laplace smoothing
# ============================================================
laplace = 1.0
CPTs = {}

def fit_cpt(child, parent_list, train_df, states_dict, laplace=1.0):
    """
    Fit CPT for P(child | parent) using MLE (with Laplace smoothing)
    
    Returns: dict parents -> {child_state: prob}
    where parents is either () (for root) or tuple of parent values
    """
    child_states = states_dict[child]
    cpt = {}
    
    # if root node, compute P(child)
    if len(parent_list) == 0:
        counts = train_df[child].value_counts()
        total = len(train_df)
        denom = total + laplace * len(child_states)
        cpt[()] = {}
        for cs in child_states:
            num = counts.get(cs, 0) + laplace
            cpt[()][cs] = num / denom
        return cpt
    
    # if non-root node, compute P(child | parents)
    parent_states_lists = [states_dict[p] for p in parent_list]
    
    for parent_cfg in product(*parent_states_lists):
        # filter rows matching parent configuration
        subset = train_df
        for p, v in zip(parent_list, parent_cfg):
            subset = subset[subset[p] == v]
        
        counts = subset[child].value_counts()
        total = len(subset)
        denom = total + laplace * len(child_states)
        
        cpt[parent_cfg] = {}
        for cs in child_states:
            num = counts.get(cs, 0) + laplace
            cpt[parent_cfg][cs] = num / denom

    return cpt

# fit CPT for each node
for node in nodes:
    CPTs[node] = fit_cpt(node, parents[node], train, states, laplace=laplace)

CPTs

# fit_cpt('age_bin', [], train, states)
# fit_cpt('education', ['age_bin', 'race', 'sex', 'native-country'], train, states)
# Out:
# {'age_bin': {(): {'Adult': np.float64(0.5041840468817975),
#    'Middle': np.float64(0.2613557847327072),
#    'Senior': np.float64(0.03705504516723392),
#    'Young': np.float64(0.19740512321826137)}},
#  'race': {(): {'Amer-Indian-Eskimo': np.float64(0.009954450074210553),
#    'Asian-Pac-Islander': np.float64(0.03063104560110548),
#    'Black': np.float64(0.09598751215517683),
#    'Other': np.float64(0.007779313168534726),
#    'White': np.float64(0.8556476790009724)}},
#  'sex': {(): {'Female': np.float64(0.33172104926423546),
#    'Male': np.float64(0.6682789507357646)}},
#  'native-country': {(): {'Asia': np.float64(0.018859233859617696),
#    'Europe': np.float64(0.01586529849791448),
#    'Latin-America': np.float64(0.03950971109803219),
#    'Missing': np.float64(0.01745182834770593),
#    'Other': np.float64(0.01069628189052944),
#    'US': np.float64(0.8976176463062002)}},
#  'education': {('Adult',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Asia'): {'Bachelors': 0.2, 'Grad': 0.2, 'HS-grad': 0.2, 'HS-or-less': 0.2, 'Some-college/Assoc': 0.2},
#   ('Adult', 'Amer-Indian-Eskimo', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.42857142857142855)},
#   ('Adult', 'Amer-Indian-Eskimo', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Other'): {'Bachelors': 0.16666666666666666, 'Grad': np.float64(0.3333333333333333), 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.05194805194805195), 'Grad': np.float64(0.07792207792207792), 'HS-grad': np.float64(0.2727272727272727), 'HS-or-less': np.float64(0.06493506493506493), 'Some-college/Assoc': np.float64(0.5324675324675324)},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'Asia'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Adult', 'Amer-Indian-Eskimo', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.1111111111111111, 'Grad': 0.1111111111111111, 'HS-grad': 0.1111111111111111, 'HS-or-less': np.float64(0.4444444444444444), 'Some-college/Assoc': np.float64(0.2222222222222222)},
#   ('Adult', 'Amer-Indian-Eskimo', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult', 'Amer-Indian-Eskimo', 'Male', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.06896551724137931), 'Grad': np.float64(0.041379310344827586), 'HS-grad': np.float64(0.46206896551724136), 'HS-or-less': np.float64(0.10344827586206896), 'Some-college/Assoc': np.float64(0.32413793103448274)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'Asia'): {'Bachelors': np.float64(0.4297520661157025), 'Grad': np.float64(0.1487603305785124), 'HS-grad': np.float64(0.1487603305785124), 'HS-or-less': np.float64(0.09917355371900827), 'Some-college/Assoc': np.float64(0.17355371900826447)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'Europe'): {'Bachelors': np.float64(0.25), 'Grad': 0.125, 'HS-grad': 0.125, 'HS-or-less': np.float64(0.25), 'Some-college/Assoc': np.float64(0.25)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'Missing'): {'Bachelors': np.float64(0.23076923076923078), 'Grad': np.float64(0.15384615384615385), 'HS-grad': np.float64(0.34615384615384615), 'HS-or-less': np.float64(0.19230769230769232), 'Some-college/Assoc': np.float64(0.07692307692307693)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.2916666666666667), 'Grad': np.float64(0.20833333333333334), 'HS-grad': np.float64(0.2916666666666667), 'HS-or-less': np.float64(0.125), 'Some-college/Assoc': np.float64(0.08333333333333333)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.2876712328767123), 'Grad': np.float64(0.0684931506849315), 'HS-grad': np.float64(0.1643835616438356), 'HS-or-less': np.float64(0.0547945205479452), 'Some-college/Assoc': np.float64(0.4246575342465753)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.259927797833935), 'Grad': np.float64(0.2996389891696751), 'HS-grad': np.float64(0.18411552346570398), 'HS-or-less': np.float64(0.07942238267148015), 'Some-college/Assoc': np.float64(0.17689530685920576)},
#   ('Adult', 'Asian-Pac-Islander', 'Male', 'Europe'): {'Bachelors': 0.125,
#    'Grad': 0.125,
#    'HS-grad': np.float64(0.375),
#    'HS-or-less': 0.125,
#    'Some-college/Assoc': np.float64(0.25)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': np.float64(0.2857142857142857), 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.2857142857142857)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.40350877192982454), 'Grad': np.float64(0.17543859649122806), 'HS-grad': np.float64(0.19298245614035087), 'HS-or-less': np.float64(0.07017543859649122), 'Some-college/Assoc': np.float64(0.15789473684210525)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.3684210526315789), 'Grad': np.float64(0.13157894736842105), 'HS-grad': np.float64(0.2631578947368421), 'HS-or-less': 0.02631578947368421, 'Some-college/Assoc': np.float64(0.21052631578947367)},
#   ('Adult',
#    'Asian-Pac-Islander',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.2767857142857143), 'Grad': np.float64(0.125), 'HS-grad': np.float64(0.24107142857142858), 'HS-or-less': np.float64(0.026785714285714284), 'Some-college/Assoc': np.float64(0.33035714285714285)},
#   ('Adult', 'Black', 'Female', 'Asia'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': 0.16666666666666666,
#    'Some-college/Assoc': np.float64(0.3333333333333333)},
#   ('Adult',
#    'Black',
#    'Female',
#    'Europe'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.1111111111111111, 'HS-grad': 0.1111111111111111, 'HS-or-less': 0.1111111111111111, 'Some-college/Assoc': np.float64(0.3333333333333333)},
#   ('Adult',
#    'Black',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.03571428571428571), 'Grad': np.float64(0.03571428571428571), 'HS-grad': np.float64(0.3392857142857143), 'HS-or-less': np.float64(0.21428571428571427), 'Some-college/Assoc': np.float64(0.375)},
#   ('Adult', 'Black', 'Female', 'Missing'): {'Bachelors': np.float64(0.2),
#    'Grad': np.float64(0.13333333333333333),
#    'HS-grad': np.float64(0.36666666666666664),
#    'HS-or-less': np.float64(0.16666666666666666),
#    'Some-college/Assoc': np.float64(0.13333333333333333)},
#   ('Adult',
#    'Black',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Adult',
#    'Black',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.1264737406216506), 'Grad': np.float64(0.03536977491961415), 'HS-grad': np.float64(0.38263665594855306), 'HS-or-less': np.float64(0.10932475884244373), 'Some-college/Assoc': np.float64(0.3461950696677385)},
#   ('Adult', 'Black', 'Male', 'Asia'): {'Bachelors': 0.125,
#    'Grad': 0.125,
#    'HS-grad': 0.125,
#    'HS-or-less': 0.125,
#    'Some-college/Assoc': np.float64(0.5)},
#   ('Adult',
#    'Black',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.2727272727272727), 'Grad': 0.09090909090909091, 'HS-grad': np.float64(0.36363636363636365), 'HS-or-less': 0.09090909090909091, 'Some-college/Assoc': np.float64(0.18181818181818182)},
#   ('Adult',
#    'Black',
#    'Male',
#    'Latin-America'): {'Bachelors': np.float64(0.0784313725490196), 'Grad': np.float64(0.13725490196078433), 'HS-grad': np.float64(0.2549019607843137), 'HS-or-less': np.float64(0.1568627450980392), 'Some-college/Assoc': np.float64(0.37254901960784315)},
#   ('Adult',
#    'Black',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.3275862068965517), 'Grad': np.float64(0.10344827586206896), 'HS-grad': np.float64(0.2413793103448276), 'HS-or-less': np.float64(0.15517241379310345), 'Some-college/Assoc': np.float64(0.1724137931034483)},
#   ('Adult',
#    'Black',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.2222222222222222), 'Grad': 0.1111111111111111, 'HS-grad': np.float64(0.2222222222222222), 'HS-or-less': np.float64(0.2222222222222222), 'Some-college/Assoc': np.float64(0.2222222222222222)},
#   ('Adult',
#    'Black',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.12903225806451613), 'Grad': np.float64(0.0389321468298109), 'HS-grad': np.float64(0.40155728587319245), 'HS-or-less': np.float64(0.12903225806451613), 'Some-college/Assoc': np.float64(0.3014460511679644)},
#   ('Adult', 'Other', 'Female', 'Asia'): {'Bachelors': np.float64(0.375),
#    'Grad': np.float64(0.25),
#    'HS-grad': 0.125,
#    'HS-or-less': 0.125,
#    'Some-college/Assoc': 0.125},
#   ('Adult', 'Other', 'Female', 'Europe'): {'Bachelors': 0.14285714285714285,
#    'Grad': 0.14285714285714285,
#    'HS-grad': np.float64(0.2857142857142857),
#    'HS-or-less': np.float64(0.2857142857142857),
#    'Some-college/Assoc': 0.14285714285714285},
#   ('Adult',
#    'Other',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.07407407407407407), 'Grad': 0.037037037037037035, 'HS-grad': np.float64(0.2962962962962963), 'HS-or-less': np.float64(0.4074074074074074), 'Some-college/Assoc': np.float64(0.18518518518518517)},
#   ('Adult',
#    'Other',
#    'Female',
#    'Missing'): {'Bachelors': np.float64(0.18181818181818182), 'Grad': np.float64(0.18181818181818182), 'HS-grad': 0.09090909090909091, 'HS-or-less': np.float64(0.36363636363636365), 'Some-college/Assoc': np.float64(0.18181818181818182)},
#   ('Adult', 'Other', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Adult',
#    'Other',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.25806451612903225), 'Grad': np.float64(0.12903225806451613), 'HS-grad': np.float64(0.25806451612903225), 'HS-or-less': np.float64(0.12903225806451613), 'Some-college/Assoc': np.float64(0.22580645161290322)},
#   ('Adult', 'Other', 'Male', 'Asia'): {'Bachelors': 0.09090909090909091,
#    'Grad': np.float64(0.2727272727272727),
#    'HS-grad': 0.09090909090909091,
#    'HS-or-less': 0.09090909090909091,
#    'Some-college/Assoc': np.float64(0.45454545454545453)},
#   ('Adult',
#    'Other',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.2857142857142857), 'Grad': np.float64(0.2857142857142857), 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': 0.14285714285714285},
#   ('Adult', 'Other', 'Male', 'Latin-America'): {'Bachelors': np.float64(0.14),
#    'Grad': 0.02,
#    'HS-grad': np.float64(0.32),
#    'HS-or-less': np.float64(0.42),
#    'Some-college/Assoc': np.float64(0.1)},
#   ('Adult',
#    'Other',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.2222222222222222), 'Grad': 0.1111111111111111, 'HS-grad': np.float64(0.2222222222222222), 'HS-or-less': 0.1111111111111111, 'Some-college/Assoc': np.float64(0.3333333333333333)},
#   ('Adult',
#    'Other',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.23076923076923078), 'Grad': np.float64(0.23076923076923078), 'HS-grad': np.float64(0.23076923076923078), 'HS-or-less': 0.07692307692307693, 'Some-college/Assoc': np.float64(0.23076923076923078)},
#   ('Adult',
#    'Other',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.1346153846153846), 'Grad': np.float64(0.057692307692307696), 'HS-grad': np.float64(0.34615384615384615), 'HS-or-less': np.float64(0.19230769230769232), 'Some-college/Assoc': np.float64(0.2692307692307692)},
#   ('Adult',
#    'White',
#    'Female',
#    'Asia'): {'Bachelors': np.float64(0.17647058823529413), 'Grad': np.float64(0.11764705882352941), 'HS-grad': np.float64(0.29411764705882354), 'HS-or-less': 0.058823529411764705, 'Some-college/Assoc': np.float64(0.35294117647058826)},
#   ('Adult',
#    'White',
#    'Female',
#    'Europe'): {'Bachelors': np.float64(0.23863636363636365), 'Grad': np.float64(0.1590909090909091), 'HS-grad': np.float64(0.26136363636363635), 'HS-or-less': np.float64(0.09090909090909091), 'Some-college/Assoc': np.float64(0.25)},
#   ('Adult',
#    'White',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.10752688172043011), 'Grad': np.float64(0.010752688172043012), 'HS-grad': np.float64(0.25806451612903225), 'HS-or-less': np.float64(0.44623655913978494), 'Some-college/Assoc': np.float64(0.1774193548387097)},
#   ('Adult',
#    'White',
#    'Female',
#    'Missing'): {'Bachelors': np.float64(0.3076923076923077), 'Grad': np.float64(0.13846153846153847), 'HS-grad': np.float64(0.15384615384615385), 'HS-or-less': np.float64(0.09230769230769231), 'Some-college/Assoc': np.float64(0.3076923076923077)},
#   ('Adult',
#    'White',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.2222222222222222), 'Grad': np.float64(0.13333333333333333), 'HS-grad': np.float64(0.24444444444444444), 'HS-or-less': np.float64(0.08888888888888889), 'Some-college/Assoc': np.float64(0.3111111111111111)},
#   ('Adult',
#    'White',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.20297259637714818), 'Grad': np.float64(0.09591267998142128), 'HS-grad': np.float64(0.30933581049698095), 'HS-or-less': np.float64(0.05945192754296331), 'Some-college/Assoc': np.float64(0.3323269856014863)},
#   ('Adult', 'White', 'Male', 'Asia'): {'Bachelors': np.float64(0.2),
#    'Grad': np.float64(0.22857142857142856),
#    'HS-grad': np.float64(0.22857142857142856),
#    'HS-or-less': np.float64(0.08571428571428572),
#    'Some-college/Assoc': np.float64(0.2571428571428571)},
#   ('Adult',
#    'White',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.2112676056338028), 'Grad': np.float64(0.15023474178403756), 'HS-grad': np.float64(0.28169014084507044), 'HS-or-less': np.float64(0.09859154929577464), 'Some-college/Assoc': np.float64(0.25821596244131456)},
#   ('Adult',
#    'White',
#    'Male',
#    'Latin-America'): {'Bachelors': np.float64(0.05357142857142857), 'Grad': np.float64(0.031746031746031744), 'HS-grad': np.float64(0.20833333333333334), 'HS-or-less': np.float64(0.5515873015873016), 'Some-college/Assoc': np.float64(0.15476190476190477)},
#   ('Adult',
#    'White',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.32275132275132273), 'Grad': np.float64(0.1746031746031746), 'HS-grad': np.float64(0.2328042328042328), 'HS-or-less': np.float64(0.1164021164021164), 'Some-college/Assoc': np.float64(0.15343915343915343)},
#   ('Adult', 'White', 'Male', 'Other'): {'Bachelors': np.float64(0.2),
#    'Grad': np.float64(0.23157894736842105),
#    'HS-grad': np.float64(0.2),
#    'HS-or-less': np.float64(0.09473684210526316),
#    'Some-college/Assoc': np.float64(0.2736842105263158)},
#   ('Adult',
#    'White',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.20753161077515117), 'Grad': np.float64(0.09098405717427158), 'HS-grad': np.float64(0.3367234744365036), 'HS-or-less': np.float64(0.07275059556532894), 'Some-college/Assoc': np.float64(0.29201026204874475)},
#   ('Middle', 'Amer-Indian-Eskimo', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Amer-Indian-Eskimo', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.2, 'Grad': 0.2, 'HS-grad': 0.2, 'HS-or-less': 0.2, 'Some-college/Assoc': 0.2},
#   ('Middle', 'Amer-Indian-Eskimo', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Amer-Indian-Eskimo', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.13636363636363635), 'Grad': np.float64(0.06818181818181818), 'HS-grad': np.float64(0.3181818181818182), 'HS-or-less': np.float64(0.18181818181818182), 'Some-college/Assoc': np.float64(0.29545454545454547)},
#   ('Middle',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Middle', 'Amer-Indian-Eskimo', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Middle', 'Amer-Indian-Eskimo', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Amer-Indian-Eskimo', 'Male', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.08), 'Grad': np.float64(0.08), 'HS-grad': np.float64(0.32), 'HS-or-less': np.float64(0.22), 'Some-college/Assoc': np.float64(0.3)},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Female',
#    'Asia'): {'Bachelors': np.float64(0.34782608695652173), 'Grad': np.float64(0.13043478260869565), 'HS-grad': np.float64(0.2391304347826087), 'HS-or-less': np.float64(0.17391304347826086), 'Some-college/Assoc': np.float64(0.10869565217391304)},
#   ('Middle', 'Asian-Pac-Islander', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': np.float64(0.3333333333333333), 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Female',
#    'Missing'): {'Bachelors': np.float64(0.2222222222222222), 'Grad': 0.1111111111111111, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': 0.1111111111111111, 'Some-college/Assoc': np.float64(0.2222222222222222)},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.2727272727272727), 'Grad': 0.09090909090909091, 'HS-grad': np.float64(0.36363636363636365), 'HS-or-less': np.float64(0.18181818181818182), 'Some-college/Assoc': 0.09090909090909091},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.10714285714285714), 'Grad': np.float64(0.07142857142857142), 'HS-grad': np.float64(0.35714285714285715), 'HS-or-less': np.float64(0.14285714285714285), 'Some-college/Assoc': np.float64(0.32142857142857145)},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.2413793103448276), 'Grad': np.float64(0.3620689655172414), 'HS-grad': np.float64(0.15517241379310345), 'HS-or-less': np.float64(0.11206896551724138), 'Some-college/Assoc': np.float64(0.12931034482758622)},
#   ('Middle', 'Asian-Pac-Islander', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': np.float64(0.3333333333333333), 'Some-college/Assoc': 0.16666666666666666},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.23076923076923078), 'Grad': np.float64(0.3076923076923077), 'HS-grad': 0.07692307692307693, 'HS-or-less': np.float64(0.15384615384615385), 'Some-college/Assoc': np.float64(0.23076923076923078)},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.42857142857142855), 'Grad': np.float64(0.09523809523809523), 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': 0.047619047619047616, 'Some-college/Assoc': np.float64(0.09523809523809523)},
#   ('Middle',
#    'Asian-Pac-Islander',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.16326530612244897), 'Grad': np.float64(0.10204081632653061), 'HS-grad': np.float64(0.2653061224489796), 'HS-or-less': np.float64(0.08163265306122448), 'Some-college/Assoc': np.float64(0.3877551020408163)},
#   ('Middle', 'Black', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Black', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Black',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.1), 'Grad': np.float64(0.06666666666666667), 'HS-grad': np.float64(0.36666666666666664), 'HS-or-less': np.float64(0.3), 'Some-college/Assoc': np.float64(0.16666666666666666)},
#   ('Middle', 'Black', 'Female', 'Missing'): {'Bachelors': 0.1,
#    'Grad': np.float64(0.2),
#    'HS-grad': np.float64(0.4),
#    'HS-or-less': 0.1,
#    'Some-college/Assoc': np.float64(0.2)},
#   ('Middle',
#    'Black',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.2857142857142857), 'Grad': 0.14285714285714285, 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.2857142857142857)},
#   ('Middle',
#    'Black',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.08706467661691543), 'Grad': np.float64(0.04228855721393035), 'HS-grad': np.float64(0.373134328358209), 'HS-or-less': np.float64(0.236318407960199), 'Some-college/Assoc': np.float64(0.26119402985074625)},
#   ('Middle', 'Black', 'Male', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Black', 'Male', 'Europe'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': np.float64(0.3333333333333333),
#    'HS-or-less': 0.16666666666666666,
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Middle',
#    'Black',
#    'Male',
#    'Latin-America'): {'Bachelors': np.float64(0.06666666666666667), 'Grad': np.float64(0.1), 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': np.float64(0.36666666666666664), 'Some-college/Assoc': np.float64(0.13333333333333333)},
#   ('Middle', 'Black', 'Male', 'Missing'): {'Bachelors': 0.06666666666666667,
#    'Grad': np.float64(0.13333333333333333),
#    'HS-grad': np.float64(0.4),
#    'HS-or-less': np.float64(0.13333333333333333),
#    'Some-college/Assoc': np.float64(0.26666666666666666)},
#   ('Middle',
#    'Black',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Middle',
#    'Black',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.12331838565022421), 'Grad': np.float64(0.0515695067264574), 'HS-grad': np.float64(0.35650224215246634), 'HS-or-less': np.float64(0.273542600896861), 'Some-college/Assoc': np.float64(0.19506726457399104)},
#   ('Middle', 'Other', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Other', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Other',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.14285714285714285), 'Grad': 0.07142857142857142, 'HS-grad': np.float64(0.35714285714285715), 'HS-or-less': np.float64(0.2857142857142857), 'Some-college/Assoc': np.float64(0.14285714285714285)},
#   ('Middle', 'Other', 'Female', 'Missing'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': np.float64(0.3333333333333333),
#    'HS-or-less': 0.16666666666666666,
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Middle', 'Other', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle',
#    'Other',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.2727272727272727), 'Grad': 0.09090909090909091, 'HS-grad': 0.09090909090909091, 'HS-or-less': np.float64(0.2727272727272727), 'Some-college/Assoc': np.float64(0.2727272727272727)},
#   ('Middle',
#    'Other',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.2857142857142857), 'Grad': np.float64(0.2857142857142857), 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': 0.14285714285714285},
#   ('Middle', 'Other', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Middle', 'Other', 'Male', 'Latin-America'): {'Bachelors': 0.04,
#    'Grad': np.float64(0.08),
#    'HS-grad': np.float64(0.24),
#    'HS-or-less': np.float64(0.52),
#    'Some-college/Assoc': np.float64(0.12)},
#   ('Middle', 'Other', 'Male', 'Missing'): {'Bachelors': 0.14285714285714285,
#    'Grad': 0.14285714285714285,
#    'HS-grad': np.float64(0.2857142857142857),
#    'HS-or-less': np.float64(0.2857142857142857),
#    'Some-college/Assoc': 0.14285714285714285},
#   ('Middle', 'Other', 'Male', 'Other'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': np.float64(0.3333333333333333),
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Middle',
#    'Other',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.15384615384615385), 'Grad': np.float64(0.23076923076923078), 'HS-grad': 0.07692307692307693, 'HS-or-less': np.float64(0.23076923076923078), 'Some-college/Assoc': np.float64(0.3076923076923077)},
#   ('Middle', 'White', 'Female', 'Asia'): {'Bachelors': 0.1,
#    'Grad': np.float64(0.2),
#    'HS-grad': 0.1,
#    'HS-or-less': np.float64(0.3),
#    'Some-college/Assoc': np.float64(0.3)},
#   ('Middle',
#    'White',
#    'Female',
#    'Europe'): {'Bachelors': np.float64(0.1527777777777778), 'Grad': np.float64(0.027777777777777776), 'HS-grad': np.float64(0.3611111111111111), 'HS-or-less': np.float64(0.20833333333333334), 'Some-college/Assoc': np.float64(0.25)},
#   ('Middle',
#    'White',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.05747126436781609), 'Grad': np.float64(0.022988505747126436), 'HS-grad': np.float64(0.25287356321839083), 'HS-or-less': np.float64(0.5517241379310345), 'Some-college/Assoc': np.float64(0.11494252873563218)},
#   ('Middle',
#    'White',
#    'Female',
#    'Missing'): {'Bachelors': np.float64(0.1951219512195122), 'Grad': np.float64(0.24390243902439024), 'HS-grad': np.float64(0.17073170731707318), 'HS-or-less': np.float64(0.21951219512195122), 'Some-college/Assoc': np.float64(0.17073170731707318)},
#   ('Middle',
#    'White',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.09090909090909091), 'Grad': np.float64(0.06818181818181818), 'HS-grad': np.float64(0.2727272727272727), 'HS-or-less': np.float64(0.22727272727272727), 'Some-college/Assoc': np.float64(0.3409090909090909)},
#   ('Middle',
#    'White',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.12409420289855072), 'Grad': np.float64(0.11277173913043478), 'HS-grad': np.float64(0.38179347826086957), 'HS-or-less': np.float64(0.09375), 'Some-college/Assoc': np.float64(0.2875905797101449)},
#   ('Middle',
#    'White',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.2222222222222222), 'Grad': np.float64(0.2222222222222222), 'HS-grad': np.float64(0.2222222222222222), 'HS-or-less': 0.1111111111111111, 'Some-college/Assoc': np.float64(0.2222222222222222)},
#   ('Middle',
#    'White',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.14685314685314685), 'Grad': np.float64(0.1258741258741259), 'HS-grad': np.float64(0.34965034965034963), 'HS-or-less': np.float64(0.22377622377622378), 'Some-college/Assoc': np.float64(0.15384615384615385)},
#   ('Middle',
#    'White',
#    'Male',
#    'Latin-America'): {'Bachelors': np.float64(0.09210526315789473), 'Grad': np.float64(0.03289473684210526), 'HS-grad': np.float64(0.20394736842105263), 'HS-or-less': np.float64(0.5855263157894737), 'Some-college/Assoc': np.float64(0.08552631578947369)},
#   ('Middle',
#    'White',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.1958762886597938), 'Grad': np.float64(0.25773195876288657), 'HS-grad': np.float64(0.1958762886597938), 'HS-or-less': np.float64(0.15463917525773196), 'Some-college/Assoc': np.float64(0.1958762886597938)},
#   ('Middle',
#    'White',
#    'Male',
#    'Other'): {'Bachelors': np.float64(0.1891891891891892), 'Grad': np.float64(0.14864864864864866), 'HS-grad': np.float64(0.20270270270270271), 'HS-or-less': np.float64(0.24324324324324326), 'Some-college/Assoc': np.float64(0.21621621621621623)},
#   ('Middle',
#    'White',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.16545213646902948), 'Grad': np.float64(0.14309373964889036), 'HS-grad': np.float64(0.33173236170917525), 'HS-or-less': np.float64(0.12172904935409076), 'Some-college/Assoc': np.float64(0.23799271281881418)},
#   ('Senior', 'Amer-Indian-Eskimo', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.2, 'Grad': 0.2, 'HS-grad': 0.2, 'HS-or-less': 0.2, 'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'US'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': np.float64(0.2857142857142857), 'HS-or-less': np.float64(0.2857142857142857), 'Some-college/Assoc': 0.14285714285714285},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'Latin-America'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Amer-Indian-Eskimo', 'Male', 'US'): {'Bachelors': 0.1,
#    'Grad': np.float64(0.2),
#    'HS-grad': np.float64(0.2),
#    'HS-or-less': np.float64(0.3),
#    'Some-college/Assoc': np.float64(0.2)},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Female',
#    'Asia'): {'Bachelors': 0.1111111111111111, 'Grad': 0.1111111111111111, 'HS-grad': 0.1111111111111111, 'HS-or-less': np.float64(0.5555555555555556), 'Some-college/Assoc': 0.1111111111111111},
#   ('Senior', 'Asian-Pac-Islander', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.2, 'Grad': 0.2, 'HS-grad': 0.2, 'HS-or-less': 0.2, 'Some-college/Assoc': 0.2},
#   ('Senior', 'Asian-Pac-Islander', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Asian-Pac-Islander', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Female',
#    'US'): {'Bachelors': 0.09090909090909091, 'Grad': 0.09090909090909091, 'HS-grad': np.float64(0.18181818181818182), 'HS-or-less': np.float64(0.36363636363636365), 'Some-college/Assoc': np.float64(0.2727272727272727)},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.4), 'Grad': 0.06666666666666667, 'HS-grad': np.float64(0.2), 'HS-or-less': np.float64(0.13333333333333333), 'Some-college/Assoc': np.float64(0.2)},
#   ('Senior', 'Asian-Pac-Islander', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Asian-Pac-Islander', 'Male', 'Latin-America'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Asian-Pac-Islander', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Male',
#    'Other'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': np.float64(0.2857142857142857), 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.2857142857142857)},
#   ('Senior',
#    'Asian-Pac-Islander',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.2727272727272727), 'Grad': 0.09090909090909091, 'HS-grad': np.float64(0.2727272727272727), 'HS-or-less': 0.09090909090909091, 'Some-college/Assoc': np.float64(0.2727272727272727)},
#   ('Senior', 'Black', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Black', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Black', 'Female', 'Latin-America'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Black', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Black', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Black',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.058823529411764705), 'Grad': np.float64(0.058823529411764705), 'HS-grad': np.float64(0.21568627450980393), 'HS-or-less': np.float64(0.47058823529411764), 'Some-college/Assoc': np.float64(0.19607843137254902)},
#   ('Senior', 'Black', 'Male', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Black', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Black',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': np.float64(0.3333333333333333), 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Senior', 'Black', 'Male', 'Missing'): {'Bachelors': 0.16666666666666666,
#    'Grad': np.float64(0.3333333333333333),
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': 0.16666666666666666,
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Senior', 'Black', 'Male', 'Other'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': np.float64(0.3333333333333333),
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Senior',
#    'Black',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.037037037037037035), 'Grad': np.float64(0.09259259259259259), 'HS-grad': np.float64(0.24074074074074073), 'HS-or-less': np.float64(0.48148148148148145), 'Some-college/Assoc': np.float64(0.14814814814814814)},
#   ('Senior', 'Other', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Other',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Senior', 'Other', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Female', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior',
#    'Other',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.3333333333333333), 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': 0.16666666666666666, 'Some-college/Assoc': 0.16666666666666666},
#   ('Senior', 'Other', 'Male', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Male', 'Latin-America'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Male', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'Other', 'Male', 'US'): {'Bachelors': 0.16666666666666666,
#    'Grad': 0.16666666666666666,
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': np.float64(0.3333333333333333),
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Senior', 'White', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Senior', 'White', 'Female', 'Europe'): {'Bachelors': 0.06666666666666667,
#    'Grad': np.float64(0.13333333333333333),
#    'HS-grad': np.float64(0.3333333333333333),
#    'HS-or-less': np.float64(0.3333333333333333),
#    'Some-college/Assoc': np.float64(0.13333333333333333)},
#   ('Senior',
#    'White',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.16666666666666666), 'Grad': 0.08333333333333333, 'HS-grad': 0.08333333333333333, 'HS-or-less': np.float64(0.4166666666666667), 'Some-college/Assoc': np.float64(0.25)},
#   ('Senior', 'White', 'Female', 'Missing'): {'Bachelors': 0.09090909090909091,
#    'Grad': np.float64(0.18181818181818182),
#    'HS-grad': np.float64(0.18181818181818182),
#    'HS-or-less': np.float64(0.2727272727272727),
#    'Some-college/Assoc': np.float64(0.2727272727272727)},
#   ('Senior',
#    'White',
#    'Female',
#    'Other'): {'Bachelors': np.float64(0.16666666666666666), 'Grad': 0.08333333333333333, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': np.float64(0.25), 'Some-college/Assoc': np.float64(0.16666666666666666)},
#   ('Senior',
#    'White',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.07769423558897243), 'Grad': np.float64(0.06265664160401002), 'HS-grad': np.float64(0.42355889724310775), 'HS-or-less': np.float64(0.17293233082706766), 'Some-college/Assoc': np.float64(0.2631578947368421)},
#   ('Senior', 'White', 'Male', 'Asia'): {'Bachelors': 0.16666666666666666,
#    'Grad': np.float64(0.3333333333333333),
#    'HS-grad': 0.16666666666666666,
#    'HS-or-less': 0.16666666666666666,
#    'Some-college/Assoc': 0.16666666666666666},
#   ('Senior',
#    'White',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.21739130434782608), 'Grad': np.float64(0.08695652173913043), 'HS-grad': np.float64(0.21739130434782608), 'HS-or-less': np.float64(0.2608695652173913), 'Some-college/Assoc': np.float64(0.21739130434782608)},
#   ('Senior', 'White', 'Male', 'Latin-America'): {'Bachelors': 0.1,
#    'Grad': np.float64(0.2),
#    'HS-grad': np.float64(0.2),
#    'HS-or-less': np.float64(0.4),
#    'Some-college/Assoc': 0.1},
#   ('Senior',
#    'White',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.2631578947368421), 'Grad': np.float64(0.2631578947368421), 'HS-grad': np.float64(0.15789473684210525), 'HS-or-less': np.float64(0.15789473684210525), 'Some-college/Assoc': np.float64(0.15789473684210525)},
#   ('Senior', 'White', 'Male', 'Other'): {'Bachelors': np.float64(0.125),
#    'Grad': np.float64(0.125),
#    'HS-grad': np.float64(0.375),
#    'HS-or-less': np.float64(0.16666666666666666),
#    'Some-college/Assoc': np.float64(0.20833333333333334)},
#   ('Senior',
#    'White',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.14251497005988023), 'Grad': np.float64(0.1341317365269461), 'HS-grad': np.float64(0.29221556886227545), 'HS-or-less': np.float64(0.23832335329341317), 'Some-college/Assoc': np.float64(0.19281437125748502)},
#   ('Young', 'Amer-Indian-Eskimo', 'Female', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young', 'Amer-Indian-Eskimo', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': np.float64(0.3333333333333333), 'Some-college/Assoc': 0.16666666666666666},
#   ('Young', 'Amer-Indian-Eskimo', 'Female', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'Other'): {'Bachelors': 0.16666666666666666, 'Grad': 0.16666666666666666, 'HS-grad': 0.16666666666666666, 'HS-or-less': np.float64(0.3333333333333333), 'Some-college/Assoc': 0.16666666666666666},
#   ('Young',
#    'Amer-Indian-Eskimo',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.047619047619047616), 'Grad': 0.023809523809523808, 'HS-grad': np.float64(0.3333333333333333), 'HS-or-less': np.float64(0.16666666666666666), 'Some-college/Assoc': np.float64(0.42857142857142855)},
#   ('Young', 'Amer-Indian-Eskimo', 'Male', 'Asia'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young', 'Amer-Indian-Eskimo', 'Male', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'Latin-America'): {'Bachelors': np.float64(0.25), 'Grad': 0.125, 'HS-grad': np.float64(0.25), 'HS-or-less': 0.125, 'Some-college/Assoc': np.float64(0.25)},
#   ('Young', 'Amer-Indian-Eskimo', 'Male', 'Missing'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young', 'Amer-Indian-Eskimo', 'Male', 'Other'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young',
#    'Amer-Indian-Eskimo',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.05263157894736842), 'Grad': 0.02631578947368421, 'HS-grad': np.float64(0.2894736842105263), 'HS-or-less': np.float64(0.34210526315789475), 'Some-college/Assoc': np.float64(0.2894736842105263)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Female',
#    'Asia'): {'Bachelors': np.float64(0.17391304347826086), 'Grad': 0.021739130434782608, 'HS-grad': np.float64(0.17391304347826086), 'HS-or-less': np.float64(0.13043478260869565), 'Some-college/Assoc': np.float64(0.5)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Female',
#    'Europe'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': 0.14285714285714285, 'HS-or-less': np.float64(0.2857142857142857), 'Some-college/Assoc': np.float64(0.2857142857142857)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Female',
#    'Latin-America'): {'Bachelors': 0.2, 'Grad': 0.2, 'HS-grad': 0.2, 'HS-or-less': 0.2, 'Some-college/Assoc': 0.2},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Female',
#    'Missing'): {'Bachelors': 0.09090909090909091, 'Grad': 0.09090909090909091, 'HS-grad': np.float64(0.2727272727272727), 'HS-or-less': 0.09090909090909091, 'Some-college/Assoc': np.float64(0.45454545454545453)},
#   ('Young', 'Asian-Pac-Islander', 'Female', 'Other'): {'Bachelors': 0.0625,
#    'Grad': 0.0625,
#    'HS-grad': np.float64(0.25),
#    'HS-or-less': np.float64(0.125),
#    'Some-college/Assoc': np.float64(0.5)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Female',
#    'US'): {'Bachelors': np.float64(0.2391304347826087), 'Grad': 0.021739130434782608, 'HS-grad': np.float64(0.2608695652173913), 'HS-or-less': np.float64(0.06521739130434782), 'Some-college/Assoc': np.float64(0.41304347826086957)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'Asia'): {'Bachelors': np.float64(0.1864406779661017), 'Grad': np.float64(0.05084745762711865), 'HS-grad': np.float64(0.2033898305084746), 'HS-or-less': np.float64(0.11864406779661017), 'Some-college/Assoc': np.float64(0.4406779661016949)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'Europe'): {'Bachelors': np.float64(0.2857142857142857), 'Grad': 0.14285714285714285, 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.2857142857142857)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'Latin-America'): {'Bachelors': 0.14285714285714285, 'Grad': 0.14285714285714285, 'HS-grad': 0.14285714285714285, 'HS-or-less': 0.14285714285714285, 'Some-college/Assoc': np.float64(0.42857142857142855)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'Missing'): {'Bachelors': np.float64(0.1875), 'Grad': 0.0625, 'HS-grad': np.float64(0.1875), 'HS-or-less': 0.0625, 'Some-college/Assoc': np.float64(0.5)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'Other'): {'Bachelors': 0.08333333333333333, 'Grad': 0.08333333333333333, 'HS-grad': np.float64(0.25), 'HS-or-less': 0.08333333333333333, 'Some-college/Assoc': np.float64(0.5)},
#   ('Young',
#    'Asian-Pac-Islander',
#    'Male',
#    'US'): {'Bachelors': np.float64(0.2727272727272727), 'Grad': np.float64(0.045454545454545456), 'HS-grad': np.float64(0.20454545454545456), 'HS-or-less': np.float64(0.045454545454545456), 'Some-college/Assoc': np.float64(0.4318181818181818)},
#   ('Young', 'Black', 'Female', 'Asia'): {'Bachelors': 0.125,
#    'Grad': 0.125,
#    'HS-grad': np.float64(0.375),
#    'HS-or-less': 0.125,
#    'Some-college/Assoc': np.float64(0.25)},
#   ('Young', 'Black', 'Female', 'Europe'): {'Bachelors': 0.2,
#    'Grad': 0.2,
#    'HS-grad': 0.2,
#    'HS-or-less': 0.2,
#    'Some-college/Assoc': 0.2},
#   ('Young',
#    'Black',
#    'Female',
#    'Latin-America'): {'Bachelors': np.float64(0.13043478260869565), 'Grad': 0.043478260869565216, 'HS-grad': np.float64(0.17391304347826086), 'HS-or-less': np.float64(0.17391304347826086), 'Some-college/Assoc': np.float64(0.4782608695652174)},
# ...
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Other-service',
#    'Full-time'): {'<=50K': np.float64(0.825), '>50K': np.float64(0.175)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Other-service',
#    'Long'): {'<=50K': np.float64(0.775), '>50K': np.float64(0.225)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Other-service',
#    'Part-time'): {'<=50K': np.float64(0.8260869565217391),
#    '>50K': np.float64(0.17391304347826086)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Priv-house-serv',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Priv-house-serv',
#    'Full-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Priv-house-serv',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Priv-house-serv',
#    'Part-time'): {'<=50K': np.float64(0.6666666666666666),
#    '>50K': 0.3333333333333333},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Prof-specialty',
#    'Extreme'): {'<=50K': np.float64(0.5333333333333333), '>50K': np.float64(0.4666666666666667)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Prof-specialty',
#    'Full-time'): {'<=50K': np.float64(0.3876651982378855),
#    '>50K': np.float64(0.6123348017621145)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Prof-specialty',
#    'Long'): {'<=50K': np.float64(0.4537037037037037), '>50K': np.float64(0.5462962962962963)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Prof-specialty',
#    'Part-time'): {'<=50K': np.float64(0.625), '>50K': np.float64(0.375)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Protective-serv',
#    'Extreme'): {'<=50K': np.float64(0.42857142857142855), '>50K': np.float64(0.5714285714285714)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Protective-serv',
#    'Full-time'): {'<=50K': np.float64(0.5416666666666666),
#    '>50K': np.float64(0.4583333333333333)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Protective-serv',
#    'Long'): {'<=50K': np.float64(0.5192307692307693), '>50K': np.float64(0.4807692307692308)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Protective-serv',
#    'Part-time'): {'<=50K': np.float64(0.8181818181818182),
#    '>50K': np.float64(0.18181818181818182)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Sales',
#    'Extreme'): {'<=50K': np.float64(0.5454545454545454), '>50K': np.float64(0.45454545454545453)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Sales',
#    'Full-time'): {'<=50K': np.float64(0.584), '>50K': np.float64(0.416)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Sales',
#    'Long'): {'<=50K': np.float64(0.4577922077922078),
#    '>50K': np.float64(0.5422077922077922)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Sales',
#    'Part-time'): {'<=50K': np.float64(0.7446808510638298), '>50K': np.float64(0.2553191489361702)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Tech-support',
#    'Extreme'): {'<=50K': np.float64(0.2727272727272727), '>50K': np.float64(0.7272727272727273)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Tech-support',
#    'Full-time'): {'<=50K': np.float64(0.44966442953020136), '>50K': np.float64(0.5503355704697986)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Tech-support',
#    'Long'): {'<=50K': np.float64(0.4307692307692308), '>50K': np.float64(0.5692307692307692)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Tech-support',
#    'Part-time'): {'<=50K': np.float64(0.4666666666666667), '>50K': np.float64(0.5333333333333333)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Transport-moving',
#    'Extreme'): {'<=50K': np.float64(0.37037037037037035),
#    '>50K': np.float64(0.6296296296296297)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Transport-moving',
#    'Full-time'): {'<=50K': np.float64(0.6631578947368421),
#    '>50K': np.float64(0.3368421052631579)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Transport-moving',
#    'Long'): {'<=50K': np.float64(0.5545454545454546), '>50K': np.float64(0.44545454545454544)},
#   ('Married-civ-spouse',
#    'Some-college/Assoc',
#    'Transport-moving',
#    'Part-time'): {'<=50K': np.float64(0.7647058823529411),
#    '>50K': np.float64(0.23529411764705882)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Adm-clerical',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Adm-clerical',
#    'Full-time'): {'<=50K': np.float64(0.8333333333333334),
#    '>50K': 0.16666666666666666},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Adm-clerical',
#    'Long'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Adm-clerical',
#    'Part-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Armed-Forces',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Armed-Forces',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Armed-Forces',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Armed-Forces',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Craft-repair',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Craft-repair',
#    'Full-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Craft-repair',
#    'Long'): {'<=50K': np.float64(0.5), '>50K': np.float64(0.5)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Craft-repair',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Exec-managerial',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Exec-managerial',
#    'Full-time'): {'<=50K': np.float64(0.6923076923076923),
#    '>50K': np.float64(0.3076923076923077)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Exec-managerial',
#    'Long'): {'<=50K': np.float64(0.4166666666666667), '>50K': np.float64(0.5833333333333334)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Exec-managerial',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Farming-fishing',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Farming-fishing',
#    'Full-time'): {'<=50K': np.float64(0.6666666666666666),
#    '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Farming-fishing',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Farming-fishing',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Handlers-cleaners',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Handlers-cleaners',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Handlers-cleaners',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Handlers-cleaners',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Machine-op-inspct',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Machine-op-inspct',
#    'Full-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Machine-op-inspct',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Machine-op-inspct',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Bachelors', 'Missing', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Missing',
#    'Full-time'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Missing',
#    'Long'): {'<=50K': np.float64(0.8), '>50K': 0.2},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Missing',
#    'Part-time'): {'<=50K': np.float64(0.8571428571428571),
#    '>50K': 0.14285714285714285},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Other-service',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Other-service',
#    'Full-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Other-service',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Other-service',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Priv-house-serv',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Priv-house-serv',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Priv-house-serv',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Priv-house-serv',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Prof-specialty',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Prof-specialty',
#    'Full-time'): {'<=50K': np.float64(0.7647058823529411),
#    '>50K': np.float64(0.23529411764705882)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Prof-specialty',
#    'Long'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Prof-specialty',
#    'Part-time'): {'<=50K': np.float64(0.5), '>50K': np.float64(0.5)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Protective-serv',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Protective-serv',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Protective-serv',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Protective-serv',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Sales',
#    'Extreme'): {'<=50K': 0.3333333333333333,
#    '>50K': np.float64(0.6666666666666666)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Sales',
#    'Full-time'): {'<=50K': np.float64(0.6), '>50K': np.float64(0.4)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Sales',
#    'Long'): {'<=50K': np.float64(0.6666666666666666),
#    '>50K': np.float64(0.3333333333333333)},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Sales',
#    'Part-time'): {'<=50K': np.float64(0.75), '>50K': 0.25},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Tech-support',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Tech-support',
#    'Full-time'): {'<=50K': np.float64(0.6666666666666666),
#    '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Tech-support',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Tech-support',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Transport-moving',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Transport-moving',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Transport-moving',
#    'Long'): {'<=50K': np.float64(0.6666666666666666),
#    '>50K': 0.3333333333333333},
#   ('Married-spouse-absent',
#    'Bachelors',
#    'Transport-moving',
#    'Part-time'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent', 'Grad', 'Adm-clerical', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Adm-clerical',
#    'Full-time'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent', 'Grad', 'Adm-clerical', 'Long'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Adm-clerical',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Armed-Forces', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Armed-Forces',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Armed-Forces', 'Long'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Armed-Forces',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Craft-repair', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Craft-repair',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Craft-repair',
#    'Long'): {'<=50K': 0.3333333333333333,
#    '>50K': np.float64(0.6666666666666666)},
#   ('Married-spouse-absent',
#    'Grad',
#    'Craft-repair',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Exec-managerial',
#    'Extreme'): {'<=50K': 0.3333333333333333,
#    '>50K': np.float64(0.6666666666666666)},
#   ('Married-spouse-absent',
#    'Grad',
#    'Exec-managerial',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Exec-managerial', 'Long'): {'<=50K': 0.2,
#    '>50K': np.float64(0.8)},
#   ('Married-spouse-absent',
#    'Grad',
#    'Exec-managerial',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Farming-fishing',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Farming-fishing',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Farming-fishing', 'Long'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Farming-fishing',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Handlers-cleaners',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Handlers-cleaners',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Handlers-cleaners',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Handlers-cleaners',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Machine-op-inspct',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Machine-op-inspct',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Machine-op-inspct',
#    'Long'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Machine-op-inspct',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Missing', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Missing',
#    'Full-time'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent', 'Grad', 'Missing', 'Long'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Missing',
#    'Part-time'): {'<=50K': np.float64(0.6666666666666666), '>50K': 0.3333333333333333},
#   ('Married-spouse-absent', 'Grad', 'Other-service', 'Extreme'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Other-service',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Other-service',
#    'Long'): {'<=50K': 0.3333333333333333,
#    '>50K': np.float64(0.6666666666666666)},
#   ('Married-spouse-absent',
#    'Grad',
#    'Other-service',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Priv-house-serv',
#    'Extreme'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Priv-house-serv',
#    'Full-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ('Married-spouse-absent', 'Grad', 'Priv-house-serv', 'Long'): {'<=50K': 0.5,
#    '>50K': 0.5},
#   ('Married-spouse-absent',
#    'Grad',
#    'Priv-house-serv',
#    'Part-time'): {'<=50K': 0.5, '>50K': 0.5},
#   ...}}

# %%
# ============================================================
# 5. Compute log-likelihood, parameter count, and BIC
# ============================================================
def compute_loglike_and_params(data_df, CPTs, parents, states, nodes, sparse_threshold=1e-4):
    loglike = 0.0
    num_params = 0
    sparsity = {n: 0 for n in nodes}
    
    # parameter count
    for child in nodes:
        child_states = states[child]
        m = len(child_states)
        parent_list = parents[child]
        
        if len(parent_list) == 0:
            num_parent_cfg = 1
        else:
            num_parent_cfg = 1
            for p in parent_list:
                num_parent_cfg *= len(states[p])
        
        # for each parent config, (m-1) free parameters
        num_params += num_parent_cfg * (m - 1)
        
        # count sparse cells for diagnostics
        for parent_cfg, dist in CPTs[child].items():
            for p in dist.values():
                if p < sparse_threshold:
                    sparsity[child] += 1
    
    # log-likelihood on given data
    for _, row in data_df.iterrows():
        for child in nodes:
            parent_list = parents[child]
            
            if len(parent_list) == 0:
                parent_cfg = ()
            else:
                parent_cfg = tuple(row[p] for p in parent_list)

            p = CPTs[child][parent_cfg].get(row[child], 1e-12)
            if p <= 0:
                p = 1e-12
            loglike += math.log(p)
    
    return loglike, num_params, sparsity

loglike, params, sparsity = compute_loglike_and_params(train, CPTs, parents, states, nodes)
bic = -2 * loglike + params * math.log(len(train))

print(f"Log-likelihood (train): {loglike:.4f}")
print(f"Number of parameters: {params}")
print(f"BIC: {bic:.4f}")
print("Sparse CPT cells per node (p < 1e-4):")
for n in nodes:
    print(f"  {n}: {sparsity[n]}")
# Out:
# Log-likelihood (train): -370733.2301
# Number of parameters: 3362
# BIC: 777013.5148
# Sparse CPT cells per node (p < 1e-4):
#   age_bin: 0
#   race: 0
#   sex: 0
#   native-country: 0
#   education: 0
#   occupation: 0
#   workclass: 0
#   hours_bin: 0
#   marital-status: 0
#   income: 0

# %%
test_preds = predict(test, CPTs, parents, states, nodes)

# Evaluate
from sklearn.metrics import accuracy_score, confusion_matrix

acc = accuracy_score(test["income"], test_preds)
cm  = confusion_matrix(test["income"], test_preds)

print("Accuracy:", acc)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.8293581738151294
# Confusion Matrix:
#  [[6871  555]
#  [1112 1231]]

# %%
def posterior_income_model2(row, CPTs, parents, states, nodes):
    income_states = states['income']
    scores = {}

    for inc in income_states:
        row_modified = row.copy()
        row_modified['income'] = inc

        inc_parents = parents['income']
        if len(inc_parents) == 0:
            parent_cfg = ()
        else:
            parent_cfg = tuple(row_modified[p] for p in inc_parents)

        p_inc = CPTs['income'][parent_cfg].get(inc, 1e-12)

        likelihood = score_row(row_modified, CPTs, parents, states, nodes)

    
        scores[inc] = p_inc * likelihood

    total = sum(scores.values())
    if total == 0:
      
        return {inc: 1.0 / len(income_states) for inc in income_states}

    return {inc: scores[inc] / total for inc in income_states}


example_post = posterior_income_model2(test.iloc[0], CPTs, parents, states, nodes)
print("Example posterior for first test row:", example_post)

def avg_p_gt50_given_model2(condition_fn):
    subset = test[condition_fn(test)]
    if len(subset) == 0:
        return 0, None

    probs = []
    for _, row in subset.iterrows():
        post = posterior_income_model2(row, CPTs, parents, states, nodes)
        probs.append(post['>50K'])

    return len(subset), sum(probs) / len(probs)

n_bach, p_bach = avg_p_gt50_given_model2(
    lambda df: df['education'] == 'Bachelors'
)

n_grad, p_grad = avg_p_gt50_given_model2(
    lambda df: df['education'].isin(['Masters', 'Doctorate', 'Prof-school'])
)

n_ft, p_ft = avg_p_gt50_given_model2(
    lambda df: df['hours_bin'] == 'Full-time'
)

n_ext, p_ext = avg_p_gt50_given_model2(
    lambda df: df['hours_bin'] == 'Extreme'
)

n_exec, p_exec = avg_p_gt50_given_model2(
    lambda df: df['occupation'] == 'Exec-managerial'
)

print("\nModel 2 posterior averages:")
print("education = Bachelors           -> n =", n_bach,  "  P(>50K) =", p_bach)
print("education = Grad (M/Dr/Prof)    -> n =", n_grad,  "  P(>50K) =", p_grad)
print("hours_bin = Full-time           -> n =", n_ft,    "  P(>50K) =", p_ft)
print("hours_bin = Extreme             -> n =", n_ext,   "  P(>50K) =", p_ext)
print("occupation = Exec-managerial    -> n =", n_exec,  "  P(>50K) =", p_exec)
# Out:
# Example posterior for first test row: {'<=50K': np.float64(0.5714285714285715), '>50K': np.float64(0.4285714285714286)}
#
# Model 2 posterior averages:
# education = Bachelors           -> n = 1633   P(>50K) = 0.4244311707553269
# education = Grad (M/Dr/Prof)    -> n = 0   P(>50K) = None
# hours_bin = Full-time           -> n = 5389   P(>50K) = 0.21410728477137653
# hours_bin = Extreme             -> n = 322   P(>50K) = 0.40647315743359197
# occupation = Exec-managerial    -> n = 1211   P(>50K) = 0.4843810998223131
